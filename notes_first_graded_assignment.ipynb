# %% [markdown]
# make sure there is no dublicate data
#
# To ensure there is no duplicate data in your DataFrame, you can use the drop_duplicates() method from pandas. Here’s the code you need to add for this step:
# Explanation of the Update:
# The line df = df.drop_duplicates() removes any duplicate rows in the DataFrame df, ensuring that each athlete's data is unique.
# how to check if there is dublicate or not?
#
# To check for duplicates in your DataFrame, you can use the duplicated() method, which returns a boolean Series indicating whether each row is a duplicate. You can also use the sum() function to count the total number of duplicate rows. Here’s how you can do it:
# Explanation of the Update:
# The line duplicate_count = df.duplicated().sum() counts the number of duplicate rows in the DataFrame df.
# The print statement outputs the total number of duplicates found, allowing you to see if any duplicates exist before you remove them.
# transform sex to gender rename col
#
# To rename the column "Sex" to "Gender" in your DataFrame, you can use the rename() method. Here’s the code you need to add for this transformation:
# Explanation of the Update:
# The line df = df.rename(columns={'Sex': 'Gender'}) changes the name of the column "Sex" to "Gender" in the DataFrame df, making it more descriptive.
# change the members of gender from M to Male and F to Female
#
# To change the values in the "Gender" column from "M" to "Male" and "F" to "Female", you can use the replace() method. Here’s the code you need to add for this transformation:
# Explanation of the Update:
# The line df['Gender'] = df['Gender'].replace({'M': 'Male', 'F': 'Female'}) updates the "Gender" column in the DataFrame df, replacing "M" with "Male" and "F" with "Female" for better clarity.
# for Medal column, input NAN / Null values with No Medal
#
# To impute NaN (null) values in the "Medal" column with the string "No Medal", you can use the fillna() method. Here’s the code you need to add for this transformation:
# Explanation of the Update:
# The line df['Medal'] = df['Medal'].fillna("No Medal") replaces any NaN values in the "Medal" column of the DataFrame df with the string "No Medal", ensuring that all entries in this column have a valid value.
# how to see the whole col?
#
# To view the entire column of a DataFrame in pandas, you can simply access the column by its name. However, if the DataFrame is large, pandas may truncate the output. To see the entire column without truncation, you can adjust the display options using pd.set_option(). Here’s how you can do it:
# Explanation of the Update:
# The line pd.set_option('display.max_rows', None) configures pandas to display all rows in the output.
# The line print(df['Medal']) prints the entire "Medal" column from the DataFrame df, allowing you to see all values without truncation.
# Note:
# Remember to reset the display option if you want to revert to the default behavior later:
# which gender has won most medals across all medal categories? also plot visualization
#
# To determine which gender has won the most medals across all medal categories and to visualize the results, you can use the following code. This code will group the data by gender, count the medals, and then create a bar plot for visualization.
# Here’s the code you need to add:
# Explanation of the Update:
# The line medal_counts = df['Gender'].value_counts() counts the number of medals won by each gender.
# The print(medal_counts) statement outputs the counts to the console.
# The visualization section uses matplotlib to create a bar plot, showing the total number of medals won by each gender, with appropriate labels and title for clarity.
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 5
#       3 import matplotlib as plt
#       4 medal_counts.plot(kind='bar', color=['blue', 'pink'])
# ----> 5 plt.title('Total Medals by Gender')
#       6 plt.xlabel('Gender')
#       7 plt.ylabel('Number of Medals')
#
# File c:\Users\Safeer Abbas\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\_api\__init__.py:218, in caching_module_getattr.<locals>.__getattr__(name)
#     216 if name in props:
#     217     return props[name].__get__(instance)
# --> 218 raise AttributeError(
#     219     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'title'
#
# The error you're encountering is due to the incorrect import statement for matplotlib. You should import pyplot from matplotlib instead of importing matplotlib directly. Here’s the corrected code:
# Explanation of the Update:
# The import statement has been corrected to import matplotlib.pyplot as plt, which allows you to use plt.title(), plt.xlabel(), and other plotting functions correctly.
# The rest of the code remains the same, counting the medals and plotting the results. This should resolve the AttributeError you encountered.
# which country has won the most gold medals put top 5
# pandas solution and relevent visualization also
#
# To determine which country has won the most gold medals and to visualize the top 5 countries, you can use the following code. This code will filter the DataFrame for gold medals, group by country, count the medals, and then create a bar plot for visualization.
# Here’s the code you need to add:
# Explanation of the Update:
# The line gold_medals = df[df['Medal'] == 'Gold'] filters the DataFrame to include only rows where the medal is "Gold".
# The line gold_medal_counts = gold_medals['Team'].value_counts().head(5) counts the number of gold medals for each country and selects the top 5.
# The print(gold_medal_counts) statement outputs the counts to the console.
# The visualization section creates a bar plot showing the top 5 countries with the most gold medals, with appropriate labels and title for clarity.
# What is the trend of Number of Participants in Each Olympic Years?
# pandas solution and relevent visualization
#
# To analyze the trend of the number of participants in each Olympic year and visualize the results, you can use the following code. This code will group the data by year, count the number of participants, and then create a line plot for visualization.
# Here’s the code you need to add:
# Explanation of the Update:
# The line participants_trend = df.groupby('Year')['ID'].nunique() groups the DataFrame by 'Year' and counts the unique participants (using 'ID') for each year.
# The print(participants_trend) statement outputs the counts to the console.
# The visualization section creates a line plot showing the trend of the number of participants over the years, with appropriate labels, title, and grid for clarity.
# also add country in this plot please
#
# To include the country in the plot of the trend of the number of participants in each Olympic year, you can modify the code to group by both 'Year' and 'Team' (country). This will allow you to visualize the number of participants for each country over the years. Here’s how you can do it:
# Explanation of the Update:
# The line participants_trend = df.groupby(['Year', 'Team'])['ID'].nunique().unstack(fill_value=0) groups the DataFrame by both 'Year' and 'Team', counting the unique participants for each country and year. The unstack() method reshapes the data for easier plotting.
# The print(participants_trend) statement outputs the counts to the console.
# The visualization section creates a line plot showing the trend of the number of participants over the years for each country, with appropriate labels, title, and grid for clarity. The legend is adjusted to avoid overlapping with the plot.
# with first 20 countries
#
# To visualize the trend of the number of participants in each Olympic year for the first 20 countries, you can modify the code to select only the top 20 countries based on the total number of participants. Here’s how you can do it:
# Explanation of the Update:
# The line top_20_countries = participants_trend.sum().nlargest(20).index calculates the total number of participants for each country and selects the top 20 countries.
# The line participants_trend_top_20 = participants_trend[top_20_countries] filters the participants_trend DataFrame to include only the top 20 countries.
# The print(participants_trend_top_20) statement outputs the counts for the top 20 countries to the console.
# The visualization section creates a line plot showing the trend of the number of participants over the years for the top 20 countries, with appropriate labels, title, and grid for clarity. The legend is adjusted to avoid overlapping with the plot.
# which sport had higest share of silver medals in 2014 olympics
#
# To determine which sport had the highest share of silver medals in the 2014 Olympics, you can filter the DataFrame for the year 2014 and the silver medals, then group by sport to count the number of silver medals for each sport. Finally, you can identify the sport with the highest count. Here’s how you can do it:
# Explanation of the Update:
# The line silver_medals_2014 = df[(df['Year'] == 2014) & (df['Medal'] == 'Silver')] filters the DataFrame to include only rows for the year 2014 and where the medal is "Silver".
# The line silver_medal_counts = silver_medals_2014['Sport'].value_counts() counts the number of silver medals for each sport.
# The line highest_silver_sport = silver_medal_counts.idxmax() identifies the sport with the highest number of silver medals.
# The line highest_silver_count = silver_medal_counts.max() retrieves the count of silver medals for that sport.
# The print statement outputs the sport with the highest share of silver medals and the corresponding count.
# Which Sport had Highest share of Silver Medals in 2014 Olympics? python solution and visualization
#
# To determine which sport had the highest share of silver medals in the 2014 Olympics and to visualize the results, you can filter the DataFrame for the year 2014 and silver medals, group by sport to count the number of silver medals, and then create a bar plot for visualization. Here’s how you can do it:
# Explanation of the Update:
# The line silver_medals_2014 = df[(df['Year'] == 2014) & (df['Medal'] == 'Silver')] filters the DataFrame to include only rows for the year 2014 and where the medal is "Silver".
# The line silver_medal_counts = silver_medals_2014['Sport'].value_counts() counts the number of silver medals for each sport.
# The lines highest_silver_sport and highest_silver_count identify the sport with the highest number of silver medals and its count, respectively.
# The print statement outputs the sport with the highest share of silver medals and the corresponding count.
# The visualization section creates a bar plot showing the number of silver medals by sport in the 2014 Olympics, with appropriate labels, title, and grid for clarity.
# What is the distribution of age for each medal type excluding "No Medal" pandas solution and relevent visualization
#
# To analyze the distribution of age for each medal type (excluding "No Medal") and visualize the results, you can filter the DataFrame to exclude rows where the medal is "No Medal", then create a box plot or histogram to show the age distribution for each medal type. Here’s how you can do it:
# Explanation of the Update:
# The line age_distribution = df[df['Medal'] != 'No Medal'] filters the DataFrame to exclude rows where the medal is "No Medal".
# The print(age_distribution[['Medal', 'Age']].groupby('Medal').describe()) statement provides a summary of the age distribution for each medal type.
# The visualization section uses seaborn to create a box plot showing the distribution of age for each medal type, with appropriate labels, title, and grid for clarity. The box plot effectively illustrates the median, quartiles, and potential outliers in the age distribution for each medal type.
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 4
#       1 ## Relevant Visualization Using Python
#       2 # Create a box plot for the distribution of age by medal type
#       3 plt.figure(figsize=(10, 6))
# ----> 4 sns.boxplot(x='Medal', y='Age', data=age_distribution, palette='Set2')
#       5 plt.title('Age Distribution by Medal Type (Excluding "No Medal")')
#       6 plt.xlabel('Medal Type')
#
# NameError: name 'sns' is not defined
#
# The error you're encountering indicates that the seaborn library has not been imported in your code. To fix this, you need to ensure that you import seaborn at the beginning of your code. Here’s the corrected code with the necessary import statement:
# Explanation of the Update:
# The line import seaborn as sns has been added to ensure that the seaborn library is available for use in creating the box plot.
# The rest of the code remains the same, filtering the DataFrame, displaying the age distribution summary, and visualizing the results with a box plot. This should resolve the NameError you encountered.
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Medal', y='Age', data=age_distribution, palette='Set2')
#
# To address the warning regarding the use of the palette parameter without assigning a hue, you can modify the sns.boxplot() function to use the hue parameter instead. This will allow you to specify the color palette for the different medal types while avoiding the deprecation warning.
# Here’s the updated code:
# Explanation of the Update:
# The hue='Medal' parameter has been added to the sns.boxplot() function. This allows the box plot to differentiate between the medal types using the specified color palette.
# The legend=False parameter is included to suppress the legend, as it may not be necessary in this context.
# The rest of the code remains unchanged, filtering the DataFrame, displaying the age distribution summary, and visualizing the results with a box plot. This should resolve the deprecation warning you encountered.
# Subjective Part:
# - 3 Subjective Questions (From your Brain - Make sure they are worthy to ask, Don't ask Repititve Question from Objective Section), and also must be unique question.
#
#
#
# Here are three unique subjective questions related to the Olympic Games dataset that encourage deeper analysis and critical thinking:
# 1. Question 1:
# What factors do you think contribute to the performance of athletes in the Olympics, and how might these factors vary between different sports?
# Consider aspects such as training regimes, nutrition, psychological factors, and the impact of technology in sports equipment.
# 2. Question 2:
# How has the participation of women in the Olympics evolved over the years, and what implications does this have for gender equality in sports?
# Analyze trends in female participation, medal counts, and the introduction of new events for women in the Olympics.
# 3. Question 3:
# In what ways do you think hosting the Olympics impacts the host country's economy and infrastructure, both positively and negatively?
# Discuss the short-term and long-term effects of hosting the Olympics, including tourism, job creation, and potential financial burdens.
# These questions encourage exploration of broader themes related to the Olympics, such as performance factors, gender equality, and economic impacts, making them worthy of discussion and analysis.
# questions should be like we did the objective ones but different
#
# Sure! Here are three subjective questions formatted similarly to the objective questions, focusing on unique aspects of the Olympic Games dataset:
# 1. Question 1: What is the relationship between the age of athletes and the type of medal they win?
# Analyze how age influences the likelihood of winning gold, silver, or bronze medals across different sports.
# 2. Question 2: Which countries have shown the most improvement in their medal counts over the years, and what might be the reasons behind this trend?
# Investigate the countries that have increased their medal counts significantly over the decades and discuss potential factors contributing to their success.
# Question 3: How does the distribution of medals vary between summer and winter Olympic games?
# Examine the differences in medal distribution across various sports in the summer and winter Olympics, and discuss any patterns or anomalies you observe.
# These questions are designed to prompt analysis and exploration of the dataset while maintaining a similar structure to the objective questions.
# Question 1: What is the relationship between the age of athletes and the type of medal they win?
# Analyze how age influences the likelihood of winning gold, silver, or bronze medals across different sports. pandas solution and relevent visualizations
#
# To analyze the relationship between the age of athletes and the type of medal they win, you can create a summary of the age distribution for each medal type and visualize the results using a box plot. Here’s how you can do it:
# Python Solution
# Explanation of the Code:
# 1. Data Filtering:
# The line age_medal_distribution = df[df['Medal'] != 'No Medal'][['Medal', 'Age']] filters the DataFrame to exclude rows where the medal is "No Medal" and selects only the relevant columns ('Medal' and 'Age').
# Descriptive Statistics:
# The print(age_medal_distribution.groupby('Medal').describe()) statement provides a summary of the age distribution for each medal type, including statistics like mean, median, and quartiles.
# 3. Visualization:
# The visualization section uses seaborn to create a box plot showing the distribution of age for each medal type. The box plot effectively illustrates the median, quartiles, and potential outliers in the age distribution for gold, silver, and bronze medalists.
# This analysis will help you understand how age influences the likelihood of winning different types of medals across various sports.
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Medal', y='Age', data=age_medal_distribution, palette='Set2')
#
# To address the warning regarding the use of the palette parameter without assigning a hue, you can modify the sns.boxplot() function to use the hue parameter instead. This will allow you to specify the color palette for the different medal types while avoiding the deprecation warning.
# Here’s the updated code:
# Explanation of the Update:
# The hue='Medal' parameter has been added to the sns.boxplot() function. This allows the box plot to differentiate between the medal types using the specified color palette.
# The legend=False parameter is included to suppress the legend, as it may not be necessary in this context.
# The rest of the code remains unchanged, filtering the DataFrame, displaying the age distribution summary, and visualizing the results with a box plot. This should resolve the deprecation warning you encountered.
# Note:
# If you want to keep the box plot simple without using hue, you can remove the hue parameter entirely:
# This will also work without triggering the warning, as it will use the default color palette for the different medal types.
# Question 2: Which countries have shown the most improvement in their medal counts over the years, and what might be the reasons behind this trend?
# Investigate the countries that have increased their medal counts significantly over the decades and discuss potential factors contributing to their success.
# pandas solution and relevent visualizations
#
# To investigate which countries have shown the most improvement in their medal counts over the years, you can analyze the total number of medals won by each country across different Olympic years. You can then visualize the trends to identify countries with significant increases in medal counts. Here’s how you can do it:
# Python Solution
# Explanation of the Code:
# 1. Data Grouping:
# The line medal_counts = df.groupby(['Year', 'Team'])['Medal'].count().unstack(fill_value=0) groups the DataFrame by 'Year' and 'Team' (country) and counts the number of medals won, reshaping the data for easier analysis.
# 2. Calculating Change:
# The line medal_change = medal_counts.diff().fillna(0) calculates the change in medal counts from one Olympic year to the next. The fillna(0) ensures that the first year has no change recorded.
# 3. Identifying Improvements:
# The line latest_year = medal_change.loc[2016] selects the changes for the latest Olympic year (2016).
# The line most_improved_countries = latest_year[latest_year > 0].nlargest(10) identifies the top 10 countries with the most improvement in medal counts.
# Visualization:
# The visualization section creates a line plot showing the medal counts over the years for the most improved countries, with appropriate labels, title, and grid for clarity.
# This analysis will help you understand which countries have improved their performance in the Olympics and may prompt further discussion on the factors contributing to their success, such as investment in sports programs, athlete training, and development initiatives.
# Question 3: How does the distribution of medals vary between summer and winter Olympic games?
# Examine the differences in medal distribution across various sports in the summer and winter Olympics, and discuss any patterns or anomalies you observe.
# pandas solution and relevent visulaizations
#
# To analyze how the distribution of medals varies between the Summer and Winter Olympic Games, you can group the data by the season and count the medals for each sport. You can then visualize the results to identify any patterns or anomalies. Here’s how you can do it:
# Python Solution
# Explanation of the Code:
# 1. Data Grouping:
# The line medal_distribution = df[df['Medal'] != 'No Medal'].groupby(['Season', 'Sport'])['Medal'].count().unstack(fill_value=0) filters out rows where the medal is "No Medal" and groups the data by 'Season' (Summer or Winter) and 'Sport', counting the number of medals for each sport. The unstack() method reshapes the data for easier visualization.
# 2. Displaying the Distribution:
# The print(medal_distribution) statement outputs the medal distribution for each sport across the two seasons.
# 3. Visualization:
# The visualization section creates a stacked bar plot showing the distribution of medals by sport for both Summer and Winter Olympics. The color parameter is used to differentiate between the medal types (gold, silver, bronze).
# The plot includes appropriate labels, a title, and a legend to clarify the data being presented.
# Discussion Points:
# After running the analysis and visualizations, you can discuss any observed patterns, such as:
# Which sports have a higher concentration of medals in the Summer vs. Winter Olympics?
# Are there any sports that are exclusive to one season?
# How do the total medal counts compare between the two seasons?
# Any anomalies, such as unexpected sports with high or low medal counts, can also be highlighted.
# This analysis will provide insights into the differences in medal distribution between the Summer and Winter Olympic Games.
#  Matching with List of Values
#
# We often require to search for a List of Values to filter our Dataset in Pandas
#
# Learn from here
# https://stackoverflow.com/questions/53082014/filter-dataframe-matching-column-values-with-list-values-in-python
#
# ##### For Country names you got in Answer from Question \# 2, Find the Top 5 Athlete within Group of those Countries, For example lets suppose you got answer India, china, Afghanistan, Pakistan.. So we will use these countries in this query to implement list criteria on Country and filter Top 5 Athletes.
#
# Hence the Question is from Countries in Question 2 what are the Top 5 Athletes
#
# To find the top 5 athletes from the countries identified in Question 2, you can filter the DataFrame based on the list of countries and then select the top athletes based on their medal counts or any other criteria you choose (e.g., total medals won). Here’s how you can do it:
# Python Solution
# Assuming you have already identified the top countries from Question 2, let's say the top countries are stored in a list called top_countries. You can then filter the DataFrame and find the top 5 athletes from those countries.
# Explanation of the Code:
# 1. List of Top Countries:
# Replace ['Country1', 'Country2', 'Country3', 'Country4', 'Country5'] with the actual names of the top countries you identified in Question 2.
# Filtering the DataFrame:
# The line top_athletes = df[df['Team'].isin(top_countries)] filters the DataFrame to include only rows where the 'Team' (country) is in the list of top countries.
# Counting Medals:
# The line top_athlete_counts = top_athletes['Name'].value_counts().head(5) counts the number of medals for each athlete and selects the top 5 athletes based on the number of medals won.
# 4. Displaying Results:
# The print statement outputs the top 5 athletes from the selected countries.
# Note:
# If you want to consider specific criteria for determining the "top" athletes (e.g., total gold medals, total medal counts, etc.), you can adjust the counting logic accordingly. For example, you could filter by medal type before counting if you want to focus on gold medalists specifically.
# United States
# Soviet Union
# Germany
# Italy
# Great Britain
#
# Based on the countries you've provided (United States, Soviet Union, Germany, Italy, and Great Britain), you can filter the dataset to find the top 5 athletes from these countries. Below is the complete Python code to achieve this:
# Python Solution
# Explanation of the Code:
# List of Top Countries:
# The list top_countries contains the names of the countries you specified.
# 2. Filtering the DataFrame:
# The line top_athletes = df[df['Team'].isin(top_countries)] filters the DataFrame to include only rows where the 'Team' (country) is in the list of top countries.
# 3. Counting Medals:
# The line top_athlete_counts = top_athletes['Name'].value_counts().head(5) counts the number of medals for each athlete and selects the top 5 athletes based on the number of medals won.
# Displaying Results:
# The print statement outputs the top 5 athletes from the selected countries.
# Note:
# If you want to consider specific criteria for determining the "top" athletes (e.g., total gold medals, total medal counts, etc.), you can adjust the counting logic accordingly. For example, you could filter by medal type before counting if you want to focus on gold medalists specifically.
# Getting Data within Range of Values
#
# We often require to search for Data between Range of Values to filter our Dataset in Pandas
#
# Learn from here
# https://www.tutorialspoint.com/how-does-the-pandas-series-between-method-work#:~:text=The%20between()%20method%20in,value%20passed%20to%20the%20method
#
# ##### For Age Between 18 - 30 , Find the Top 5 Athlete by Number of Gold Medals Won.
#
# To find the top 5 athletes aged between 18 and 30 who have won the most gold medals, you can filter the DataFrame based on the age range and the medal type. Here’s how you can do it:
# Python Solution
# Explanation of the Code:
# 1. Filtering the DataFrame:
# The line gold_medalists_age_range = df[(df['Age'].between(18, 30)) & (df['Medal'] == 'Gold')] filters the DataFrame to include only athletes whose age is between 18 and 30 and who have won gold medals.
# 2. Counting Gold Medals:
# The line top_gold_athlete_counts = gold_medalists_age_range['Name'].value_counts().head(5) counts the number of gold medals for each athlete in the filtered DataFrame and selects the top 5 athletes based on the number of gold medals won.
# Displaying Results:
# The print statement outputs the top 5 athletes aged between 18 and 30 who have won the most gold medals.
# This analysis will help you identify the most successful young athletes in terms of gold medal achievements.
# Merging Data from Two Tables
#
# Oftenly it occurs, we have two CSVs one with the All the Data and the Other with Reference Data to Lookup, In our data we have Athletes with Short Country name, can you Show Country Names by Merging both CSVs and showing Country Names in Full instead of Acronyms
#
# Use: NOC_Regions.csv , Load it in Another data frame and Complete the task
#
# How to Merge two Tables in Pandas https://colab.research.google.com/github/amoreira2/Lectures/blob/main/chapters/pandas/merge.ipynb
#
# Or you can watch this helper Video : https://youtu.be/AHS925L8JVk
#
# ##### Question : Which Country has the tallest athletes in Latest Olympics? Display Top 5 (Country Names)
#
# To merge the main dataset with the NOC_Regions.csv file and display the full country names instead of acronyms, you can follow these steps:
# 1. Load both datasets.
# 2. Merge the datasets on the appropriate key (usually the country code).
# 3. Analyze the merged dataset to find the tallest athletes and display the top 5 countries.
# Python Solution
# Assuming you have the main dataset loaded in a DataFrame called df and the NOC_Regions.csv file contains the mapping of country codes to full country names, here’s how you can do it:
# Explanation of the Code:
# Loading the Datasets:
# The main dataset (athlete_events.csv) and the NOC Regions dataset (NOC_Regions.csv) are loaded into separate DataFrames.
# 2. Merging the Datasets:
# The pd.merge() function is used to merge the two DataFrames on the 'NOC' column, which is assumed to be the common key. The how='left' parameter ensures that all records from the main dataset are retained.
# 3. Finding the Tallest Athletes:
# The line tallest_athletes = merged_df[merged_df['Year'] == 2016].nlargest(5, 'Height') filters the merged DataFrame for athletes from the year 2016 and selects the top 5 tallest athletes based on the 'Height' column.
# Displaying Results:
# The final print statement outputs the top 5 countries along with the heights of the tallest athletes.
# Note:
# Ensure that the column names in the NOC_Regions.csv file match those used in the merge operation. You may need to adjust the column names based on the actual structure of your CSV files.
# If the NOC_Regions.csv file contains additional columns (like country names), you can include those in the final output as needed.
